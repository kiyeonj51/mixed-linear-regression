# %%
import sys
sys.path.append('..')

from mlr.cores.data import *
from mlr.cores.loss import *
from mlr.utils.initialize import *
from mlr.cores.base import (EM, EMP, RR, EMRR, RRONE, ARR)

# Example setting
params = {
    "data_name": DataMLR,
    "init_method": init_rand_normal,
    "reg": 0,
    "n": 1000,
    "d": 50,
    "s": 50,
    "max_iter": 100,
    "p1": .7,
    "std": 0,
    "num_simulation": 10
}
funcs = (func_mlr,  None, None)

mlr_algorithms = [
    ("EM", EM(funcs=funcs, max_iter=params['max_iter'], info="EM")),
    ("EMP", EMP(funcs=funcs, max_iter=params['max_iter'], info="EMP")),
    ("RR", RR(funcs=funcs, max_iter=params['max_iter'], info="RR")),
    ("EMRR", EMRR(funcs=funcs,max_iter=params['max_iter'], info="EMRR")),
    ("RRONE", RRONE(funcs=funcs, max_iter=params['max_iter'], info="RRONE")),
]

for i in range(params['num_simulation']):
    print(f'\n{i}-th simulation')
    # generate data
    dataset = params['data_name']
    data = dataset.generate_data(params)

    # optimize
    results = []
    for name, algorithm in mlr_algorithms:
        res = algorithm.solve(data=data,init_method=params['init_method'])
        results.append(res)
# Out:
# Using TensorFlow backend.
# 0-th simulation
# inner product of two vectors is -0.09823684559695808
# EM|tr_error : 0.000000, reg : 0.0000000e+00, te_error : 0.000000, beta_error : 0.000000
# EMP|tr_error : 0.133475, reg : 0.0000000e+00, te_error : 0.262934, beta_error : 0.420634
# RR|tr_error : 0.000008, reg : 0.0000000e+00, te_error : 0.017744, beta_error : 0.001109
# EMRR|tr_error : 0.000000, reg : 0.0000000e+00, te_error : 0.000000, beta_error : 0.000000
# RRONE|tr_error : 0.039097, reg : 0.0000000e+00, te_error : 0.160521, beta_error : 0.092547
#
# 1-th simulation
# inner product of two vectors is 0.19057819534918816
# EM|tr_error : 0.000000, reg : 0.0000000e+00, te_error : 0.000000, beta_error : 0.000000
# EMP|tr_error : 0.141958, reg : 0.0000000e+00, te_error : 0.260498, beta_error : 0.635168
# RR|tr_error : 0.012977, reg : 0.0000000e+00, te_error : 0.005130, beta_error : 0.128638
# EMRR|tr_error : 0.000000, reg : 0.0000000e+00, te_error : 0.000000, beta_error : 0.000000
# RRONE|tr_error : 0.031139, reg : 0.0000000e+00, te_error : 0.045857, beta_error : 0.089181
#
# 2-th simulation
# inner product of two vectors is 0.04933040754416153
# EM|tr_error : 0.000000, reg : 0.0000000e+00, te_error : 0.000000, beta_error : 0.000000
# EMP|tr_error : 0.335949, reg : 0.0000000e+00, te_error : 0.418805, beta_error : 0.846765
# RR|tr_error : 0.000001, reg : 0.0000000e+00, te_error : 0.032298, beta_error : 0.000390
# EMRR|tr_error : 0.000000, reg : 0.0000000e+00, te_error : 0.000000, beta_error : 0.000000
# RRONE|tr_error : 0.050779, reg : 0.0000000e+00, te_error : 0.095793, beta_error : 0.098260
#
# 3-th simulation
# inner product of two vectors is 0.26227404669997567
# EM|tr_error : 0.116338, reg : 0.0000000e+00, te_error : 0.215578, beta_error : 0.909092
# EMP|tr_error : 0.158754, reg : 0.0000000e+00, te_error : 0.203438, beta_error : 0.453608
# RR|tr_error : 0.006980, reg : 0.0000000e+00, te_error : 0.002902, beta_error : 0.097659
# EMRR|tr_error : 0.000000, reg : 0.0000000e+00, te_error : 0.000000, beta_error : 0.000000
# RRONE|tr_error : 0.037079, reg : 0.0000000e+00, te_error : 0.168198, beta_error : 0.086854
#
# 4-th simulation
# inner product of two vectors is 0.13444175552480714
# EM|tr_error : 0.000000, reg : 0.0000000e+00, te_error : 0.000000, beta_error : 0.000000
# EMP|tr_error : 0.192892, reg : 0.0000000e+00, te_error : 0.257677, beta_error : 0.592612
# RR|tr_error : 0.001603, reg : 0.0000000e+00, te_error : 0.000452, beta_error : 0.048947
# EMRR|tr_error : 0.000000, reg : 0.0000000e+00, te_error : 0.000000, beta_error : 0.000000
# RRONE|tr_error : 0.036909, reg : 0.0000000e+00, te_error : 0.099559, beta_error : 0.096495
#
# 5-th simulation
# inner product of two vectors is 0.2562147703880975
# EM|tr_error : 0.000000, reg : 0.0000000e+00, te_error : 0.000000, beta_error : 0.000000
# EMP|tr_error : 0.225863, reg : 0.0000000e+00, te_error : 0.299870, beta_error : 0.588453
# RR|tr_error : 0.016998, reg : 0.0000000e+00, te_error : 0.009627, beta_error : 0.186340
# EMRR|tr_error : 0.000000, reg : 0.0000000e+00, te_error : 0.000000, beta_error : 0.000000
# RRONE|tr_error : 0.051648, reg : 0.0000000e+00, te_error : 0.207039, beta_error : 0.115890
#
# 6-th simulation
# inner product of two vectors is 0.07278108461212472
# EM|tr_error : 0.000000, reg : 0.0000000e+00, te_error : 0.000000, beta_error : 0.000000
# EMP|tr_error : 0.170576, reg : 0.0000000e+00, te_error : 0.224393, beta_error : 0.387814
# RR|tr_error : 0.000021, reg : 0.0000000e+00, te_error : 0.032577, beta_error : 0.001852
# EMRR|tr_error : 0.000000, reg : 0.0000000e+00, te_error : 0.000000, beta_error : 0.000000
# RRONE|tr_error : 0.059573, reg : 0.0000000e+00, te_error : 0.240917, beta_error : 0.110590
#
# 7-th simulation
# inner product of two vectors is 0.14879401137352033
# EM|tr_error : 0.000000, reg : 0.0000000e+00, te_error : 0.000000, beta_error : 0.000000
# EMP|tr_error : 0.222432, reg : 0.0000000e+00, te_error : 0.337403, beta_error : 0.653678
# RR|tr_error : 0.000004, reg : 0.0000000e+00, te_error : 0.023141, beta_error : 0.000933
# EMRR|tr_error : 0.000000, reg : 0.0000000e+00, te_error : 0.000000, beta_error : 0.000000
# RRONE|tr_error : 0.050172, reg : 0.0000000e+00, te_error : 0.160400, beta_error : 0.116058
#
# 8-th simulation
# inner product of two vectors is 0.014996604373589913
# EM|tr_error : 0.000000, reg : 0.0000000e+00, te_error : 0.000000, beta_error : 0.000000
# EMP|tr_error : 0.217571, reg : 0.0000000e+00, te_error : 0.401322, beta_error : 0.725532
# RR|tr_error : 0.000000, reg : 0.0000000e+00, te_error : 0.009622, beta_error : 0.000000
# EMRR|tr_error : 0.000000, reg : 0.0000000e+00, te_error : 0.000000, beta_error : 0.000000
# RRONE|tr_error : 0.041212, reg : 0.0000000e+00, te_error : 0.203649, beta_error : 0.109223
#
# 9-th simulation
# inner product of two vectors is -0.0441606389636527
# EM|tr_error : 0.000000, reg : 0.0000000e+00, te_error : 0.000000, beta_error : 0.000000
# EMP|tr_error : 0.251756, reg : 0.0000000e+00, te_error : 0.417200, beta_error : 0.827937
# RR|tr_error : 0.014568, reg : 0.0000000e+00, te_error : 0.006196, beta_error : 0.156242
# EMRR|tr_error : 0.000000, reg : 0.0000000e+00, te_error : 0.000000, beta_error : 0.000000
# RRONE|tr_error : 0.036765, reg : 0.0000000e+00, te_error : 0.055278, beta_error : 0.077942
